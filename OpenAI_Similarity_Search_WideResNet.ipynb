# %% [markdown]
# <a href="https://colab.research.google.com/github/nmamatsashvili/OpenAI-Image-Similarity/blob/master/OpenAI_Similarity_Search_WideResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
# or WRN-101-2
model = torch.hub.load('pytorch/vision:v0.10.0', 'wide_resnet101_2', pretrained=True)
model.eval()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("insert data")
import os
import time

lstResultSimilarity = []
stmtIds = []
stmtIdsUnvisited = []
start = time.perf_counter()
dir = "/content/drive/MyDrive/Colab Notebooks/data/responses_test_5"
dataFile = "WideResNet.txt"
FileExists = os.path.exists(dataFile)

if FileExists :
    file = open(dataFile,"r+")
    file.truncate()
    file.close()
# Out:
# insert data

# %%
print("get all statement IDs")
stmtIds = []
for folder in os.listdir(dir):
    stmtIds.append(folder)
stmtIdsUnvisited = list(stmtIds)
openFile = open(dataFile, "a")
end = time.perf_counter()
print("time before iteration: " + str( round(end - start, 2)) + " seconds")
print(str(len(stmtIds)) + " statements")
start = time.perf_counter()
# Out:
# get all statement IDs
# time before iteration: 1.92 seconds
# 5 statements

# %%
# sample execution (requires torchvision)
from PIL import Image
import torch.nn as nn
from torchvision import transforms
from sentence_transformers import SentenceTransformer, util
def calculateCosineSimilarity(imagePath1, imagePath2):
  input_image = Image.open(imagePath1) 
  input_image2 = Image.open(imagePath2)
  preprocess = transforms.Compose([
      transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
  ])
  input_tensor = preprocess(input_image)
  input_tensor2 = preprocess(input_image2)
  input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model
  input_batch2 = input_tensor2.unsqueeze(0) # create a mini-batch as expected by the model

  # move the input and model to GPU for speed if available
  if torch.cuda.is_available():
      
      input_batch = input_batch.to('cuda')
      input_batch2 = input_batch2.to('cuda')
      model.to('cuda')

  # Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
  with torch.no_grad():
      output = model(input_batch)
      output2 = model(input_batch2)

  return util.cos_sim(output, output2)

# %%
pip install -U sentence-transformers

# %%
print("iterate over each statement pictures to find similarity")
from PIL import Image
import os
import time
from sentence_transformers import SentenceTransformer, util


cnt = 0
for stmt in stmtIds:
    stmtIdsUnvisited.remove(stmt)
    lstImagesCurrent = []
    
    for image in os.listdir(dir + "/" + stmt):
        if os.fsdecode(image).endswith(".jpg") == False:
            continue
        lstImagesCurrent.append(Image.open(f"{dir}/{stmt}/{image}").convert('RGB'))

    
    for img_lst in lstImagesCurrent:
        
        for stmtNext in stmtIdsUnvisited:
            lstImagesNext = []
            for imageNext in os.listdir(dir + "/" + stmtNext):
                if os.fsdecode(imageNext).endswith(".jpg") == False:
                    continue
                lstImagesNext.append(Image.open(f"{dir}/{stmtNext}/{imageNext}").convert('RGB')) 
                rst = calculateCosineSimilarity(f"{dir}/{stmt}/{image}", f"{dir}/{stmtNext}/{imageNext}")
                print("dir1: " + f"{dir}/{stmt}/{image}" + " ----- dir2: " + f"{dir}/{stmtNext}/{imageNext}" + " RST:" + str(rst))
                #result = f"statements: {stmt} vs {stmtNext} - images: {img_lst} vs {imageNext}" 
                #lstResultSimilarity.append({"id1":stmt, "id2":stmtNext, "img1":img_lst, "img2":imageNext})
                #openFile.write("\n" + result)
                cnt +=1
            
                
                

    print("success statement " + str(stmt))
print("end iteration " + str(cnt))
# Out:
# iterate over each statement pictures to find similarity
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896
], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/7.jpg RST:tensor([[0.5023]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/10.jpg RST:tensor([[0.7439]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/5.jpg RST:tensor([[0.7293]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/8.jpg RST:tensor([[0.4495]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/1.jpg RST:tensor([[0.4366]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/3.jpg RST:tensor([[0.5880]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg RST:tensor([[0.3419]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.6190]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.6884]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.5955]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.5872]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.4405]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.6594]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[0.3150]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.6102]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.5959]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.7337]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896/2.jpg RST:tensor([[0.4614]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896/5.jpg RST:tensor([[0.6386]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896/1.jpg RST:tensor([[0.5129]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896/3.jpg RST:tensor([[0.2761]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896/4.jpg RST:tensor([[0.4197]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5098896/6.jpg RST:tensor([[0.4984]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5099944/6.jpg RST:tensor([[0.6906]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5099944/2.jpg RST:tensor([[0.7743]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5099944/4.jpg RST:tensor([[0.7386]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5099944/3.jpg RST:tensor([[0.6144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5099944/1.jpg RST:tensor([[0.7147]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5099944/5.jpg RST:tensor([[0.7219]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/6.jpg RST:tensor([[0.5101]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/9.jpg RST:tensor([[0.6861]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/4.jpg RST:tensor([[0.6699]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/2.jpg RST:tensor([[0.7485]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/7.jpg RST:tensor([[0.5023]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/10.jpg RST:tensor([[0.7439]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/5.jpg RST:tensor([[0.7293]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/8.jpg RST:tensor([[0.4495]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/1.jpg RST:tensor([[0.4366]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/3.jpg RST:tensor([[0.5880]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg RST:tensor([[0.3419]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.6190]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.6884]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.5955]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.5872]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.4405]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.6594]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[0.3150]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.6102]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5096981/8.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.5959]], device='cuda:0')
# ...
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/3.jpg RST:tensor([[0.4327]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/4.jpg RST:tensor([[0.3521]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/5.jpg RST:tensor([[0.2271]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/10.jpg RST:tensor([[0.1814]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/1.jpg RST:tensor([[0.6719]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/8.jpg RST:tensor([[0.3000]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/2.jpg RST:tensor([[-0.0409]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/7.jpg RST:tensor([[0.4144]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/6.jpg RST:tensor([[0.3979]], device='cuda:0')
# dir1: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100573/11.jpg ----- dir2: /content/drive/MyDrive/Colab Notebooks/data/responses_test_5/5100792/9.jpg RST:tensor([[0.3145]], device='cuda:0')
# success statement 5100573
# success statement 5100792
# end iteration 695

# %%
rst = calculateCosineSimilarity("/content/drive/MyDrive/Colab Notebooks/data/my_data/aa1.jpg", "/content/drive/MyDrive/Colab Notebooks/data/my_data/aa2.jpg")
print(rst)
# Out:
# tensor([[0.8964]], device='cuda:0')
